# %%
# !nvidia-smi
# Out:
# Tue Jun  6 19:26:20 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 516.94       Driver Version: 516.94       CUDA Version: 11.7     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name            TCC/WDDM | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA GeForce ... WDDM  | 00000000:02:00.0  On |                  N/A |
# | 29%   34C    P8     8W / 125W |    714MiB /  6144MiB |      2%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !python -m pip install -U pip wheel
# !pip install -U ipython 
# !pip install -U so-vits-svc-fork

# %%
# !svc pre-split --frame-seconds=0.1 --input-dir=dataset_raw/test --output-dir=dataset_raw/test_split
# Out:
# ...
# Writing dataset_raw\test\Запись.wav: 100%|##########| 1/1 [00:00<00:00, 111.44it/s]
#
# ...
# Writing dataset_raw\test\Запись (3).wav: 100%|##########| 1/1 [00:00<00:00, 100.31it/s]
#
# ...
# Writing dataset_raw\test\Запись (2).wav: 100%|##########| 1/1 [00:00<00:00, 144.05it/s]
#
# ...
# Writing dataset_raw\test\Запись (5).wav: 100%|##########| 1/1 [00:00<00:00, 125.93it/s]
#
# ...
# Writing dataset_raw\test\Запись (4).wav: 100%|##########| 1/1 [00:00<00:00, 125.37it/s]
#
# Splitting: 100%|##########| 5/5 [00:04<00:00,  1.17it/s]

# %%
# !svc pre-resample --input-dir=dataset_raw/ --output-dir=./dataset/44k
# Out:
# ...
# Preprocessing: 100%|##########| 10/10 [00:05<00:00,  1.95it/s]

# %%
# !svc pre-config
# Out:
# [19:39:40] INFO     [19:39:40] Writing            preprocess_flist_config.py:54
#                     filelists\44k\train.txt
#            INFO     [19:39:40] Writing            preprocess_flist_config.py:60
#                     filelists\44k\val.txt
#            INFO     [19:39:40] Writing            preprocess_flist_config.py:64
#                     filelists\44k\test.txt
#            INFO     [19:39:40] Writing            preprocess_flist_config.py:83
#                     configs\44k\config.json
# ...
# 100%|##########| 5/5 [00:00<00:00, 364.18it/s]
#
# ...
# 100%|##########| 5/5 [00:00<00:00, 385.64it/s]

# %%
F0_METHOD = "dio" #@param ["crepe", "crepe-tiny", "parselmouth", "dio", "harvest"]
# !svc pre-hubert -fm {F0_METHOD}
# Out:
# [19:41:51] INFO     [19:41:51] n_jobs automatically preprocess_hubert_f0.py:142
#                     set to 2, memory: 6144 MiB
# [19:41:52] WARNING  [19:41:52]                                  warnings.py:109
#                     C:\Users\Pavel\PycharmProjects\voiceModel\v
#                     env\lib\site-packages\huggingface_hub\file_
#                     download.py:133: UserWarning:
#                     `huggingface_hub` cache-system uses
#                     symlinks by default to efficiently store
#                     duplicated files but your machine does not
#                     support them in
#                     C:\Users\Pavel\.cache\huggingface\hub.
#                     Caching files will still work but in a
#                     degraded version that might require more
#                     space on your disk. This warning can be
#                     disabled by setting the
#                     `HF_HUB_DISABLE_SYMLINKS_WARNING`
# ...

# %%
# !svc train --model-path configs/44k
